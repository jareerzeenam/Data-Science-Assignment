# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('GlobalTemperature.csv')

# %%
data
# Out:
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0    1880 -0.17 -0.23 -0.08 -0.15 -0.09 -0.20 -0.17 -0.09 -0.14 -0.22 -0.21
# 1    1881 -0.18 -0.13  0.04  0.06  0.07 -0.17  0.01 -0.02 -0.14 -0.20 -0.17
# 2    1882  0.18  0.15  0.06 -0.15 -0.14 -0.22 -0.15 -0.06 -0.14 -0.23 -0.15
# 3    1883 -0.28 -0.36 -0.12 -0.18 -0.17 -0.06 -0.07 -0.13 -0.21 -0.11 -0.23
# 4    1884 -0.12 -0.08 -0.36 -0.39 -0.34 -0.34 -0.32 -0.27 -0.27 -0.24 -0.32
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 135  2015  0.86  0.90  0.96  0.77  0.79  0.82  0.75  0.83  0.85  1.08  1.06
# 136  2016  1.17  1.37  1.36  1.12  0.96  0.82  0.84  1.01  0.91  0.88  0.91
# 137  2017  1.03  1.14  1.16  0.94  0.90  0.72  0.82  0.87  0.79  0.90  0.88
# 138  2018  0.82  0.85  0.90  0.90  0.82  0.78  0.82  0.77  0.80  1.01  0.83
# 139  2019  0.93  0.95  1.18  1.02  0.86  0.92  0.94  0.94  0.92  1.02  1.00
#
#       Dec   J-D    D-N    DJF   MAM   JJA   SON
# ...

# %%
plt.scatter(data['Year'],data['Apr'])
# Set limits of the axes, again to resemble the world map
plt.xlim(1880,2020)
plt.ylim(-0.50,1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x = sm.add_constant(data['Year'])
results = sm.OLS(data['Apr'],x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    Apr   R-squared:                       0.694
# Model:                            OLS   Adj. R-squared:                  0.692
# Method:                 Least Squares   F-statistic:                     313.4
# Date:                Thu, 16 Jan 2020   Prob (F-statistic):           2.48e-37
# Time:                        20:12:48   Log-Likelihood:                 23.431
# No. Observations:                 140   AIC:                            -42.86
# Df Residuals:                     138   BIC:                            -36.98
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -14.8392      0.841    -17.652      0.000     -16.502     -13.177
# ...

# %%
plt.scatter(data['Year'],data['Apr'])
yhat = 0.0076*data['Year'] + -14.8392
fig = plt.plot(data['Year'],yhat, lw=4, c='orange',label='regression line')
# Set limits of the axes, again to resemble the world map
plt.xlim(1880,2020)
plt.ylim(-0.50,1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
