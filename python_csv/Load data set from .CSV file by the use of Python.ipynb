# %%
import csv

# %%
with open('global-temperature-1.csv', 'r') as csvfile:
    reader = csv.reader(csvfile, skipinitialspace=True)
    for row in reader:
        print(row)
# Out:
# ['cartodb_id', 'the_geom', 'the_geom_webmercator', 'uid', 'date', 'value', 'value_type']
# ['1', '', '', 'annual_mean_1880-01-01', '1880-01-01T00:00:00Z', '-0.2', 'annual_mean']
# ['2', '', '', 'five_year_mean_1880-01-01', '1880-01-01T00:00:00Z', '-0.13', 'five_year_mean']
# ['3', '', '', 'annual_mean_1881-01-01', '1881-01-01T00:00:00Z', '-0.12', 'annual_mean']
# ['4', '', '', 'five_year_mean_1881-01-01', '1881-01-01T00:00:00Z', '-0.16', 'five_year_mean']
# ['5', '', '', 'annual_mean_1882-01-01', '1882-01-01T00:00:00Z', '-0.1', 'annual_mean']
# ['6', '', '', 'five_year_mean_1882-01-01', '1882-01-01T00:00:00Z', '-0.19', 'five_year_mean']
# ['7', '', '', 'annual_mean_1883-01-01', '1883-01-01T00:00:00Z', '-0.21', 'annual_mean']
# ['8', '', '', 'five_year_mean_1883-01-01', '1883-01-01T00:00:00Z', '-0.21', 'five_year_mean']
# ['9', '', '', 'annual_mean_1884-01-01', '1884-01-01T00:00:00Z', '-0.28', 'annual_mean']
# ...
